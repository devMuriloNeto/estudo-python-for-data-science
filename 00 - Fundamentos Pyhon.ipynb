# %% [markdown]
# <h1>Função print<h1>

# %%
print("Olá, mundo!")
# Out:
# Olá, mundo!

# %%
print("A pequenina aranha\ne subiu a tromba d'agua.")
print()
print("Caiu a chuva te lavou a aranha.")
print("\\")
# Out:
# A pequenina aranha
# e subiu a tromba d'agua.
#
# Caiu a chuva te lavou a aranha.
# \

# %%
print("A aranha pequenininha" , "subiu" , "a tromba d'água.")
print("A aranha pequenininha","subiu","a tromba d'água.")
# Out:
# A aranha pequenininha subiu a tromba d'água.
# A aranha pequenininha subiu a tromba d'água.

# %%
print("Meu nome é", "Python.")
print("Monty Python.")
# Out:
# Meu nome é Python.
# Monty Python.

# %%
print("Meu nome é", "Python.", end=" ")
print("Monty Python.")
# Out:
# Meu nome é Python. Monty Python.

# %%
print("Meu", "nome", "é", "Monty", "Python.", sep="-")
# Out:
# Meu-nome-é-Monty-Python.

# %%
print("Programação","Essenciais","em", sep="***", end="...")
print("Python")
# Out:
# Programação***Essenciais***em...Python

# %% [markdown]
# <h1>Variáveis<h1>

# %%
nome = "Murilo Neto"
idade = 25
sexo = "M"
altura = "1.65"
casado = True

# %%
print('nome:', nome)
print('idade:', idade)
print('Sexo:', sexo)
print('Altura:', altura)
print('Casado:', casado)
# Out:
# nome: Murilo Neto
# idade: 25
# Sexo: M
# Altura: 1.65
# Casado: True

# %% [markdown]
# <h1>Tipos<h1>

# %%
print("2")
print(2)
# Out:
# 2
# 2

# %%
print(0x123)
print(0o123)
# Out:
# 291
# 83

# %%
3e8
# Out:
# 300000000.0

# %%
print(True > False)
print(True < False)
# Out:
# True
# False

# %% [markdown]
# <h1>Scape<h1>

# %%
print('\"Eu sou\"\n\"\"aprendizado\"\"\n\"\"\"Python\"\"\"')
# Out:
# "Eu sou"
# ""aprendizado""
# """Python"""

# %% [markdown]
# <h1>Operações aritiméticas<h1>

# %%
print(int("1011", 2))
# Out:
# 11

# %%
print(85%2)
# Out:
# 1

# %%
print(2 ** 3)
print(2 ** 3.)
print(2. ** 3)
print(2. ** 3.)
# Out:
# 8
# 8.0
# 8.0
# 8.0

# %%
print(6 / 3)
print(6 / 3.)
print(6. / 3)
print(6. / 3.)
# Out:
# 2.0
# 2.0
# 2.0
# 2.0

# %%
print(6 // 3)
print(6 // 3.)
print(6. // 3)
print(6. // 3.)
# Out:
# 2
# 2.0
# 2.0
# 2.0

# %%
print(-6 // 4)
print(6. // -4)
# Out:
# -2
# -2.0

# %%
print(14 % 4)
print(12 % 4.5)
# Out:
# 2
# 3.0

# %%
print(-4 + 4)
print(-4. + 8)
# Out:
# 0
# 4.0

# %%
print(-4 - 4)
print(4. - 8)
print(-1.1)
# Out:
# -8
# -4.0
# -1.1

# %%
print(2 ** 2 ** 3)
# Out:
# 256

# %%
print(-3 ** 2)
print(-2 ** 3)
print(-(3 ** 2))
# Out:
# -9
# -8
# -9

# %%
var = 1
print(var)
# Out:
# 1

# %%
var = 1
account_balance = 1000.0
client_name = 'John Doe'
print(var, account_balance, client_name)
print(var)
# Out:
# 1 1000.0 John Doe
# 1

# %%
var = 1
print(var)
var = var + 1
print(var)
# Out:
# 1
# 2

# %%
var = 1
print(var)
var = var + 1
print(var)
# Out:
# 1
# 2

# %%
john = 3
mary = 5
adam = 6

total_apples = john + mary + adam

print(total_apples)
# Out:
# 14

# %%
john = 3
mary = 5
adam = 6

total_apples = john + mary + adam

print('Número total de maçãs:', total_apples)

print('John possui ', john, 'maçãs')
print('Mary possui ', mary, 'maçãs')
print('Adam possui ', adam, 'maçãs')
# Out:
# Número total de maçãs: 14
# John possui  3 maçãs
# Mary possui  5 maçãs
# Adam possui  6 maçãs

# %%
person = ['John','Mary','Adam']
apples = [3,5,6]

print(apples)

for i in range (3):
    print(person[i], 'possui', apples[i], 'maçãs')
# Out:
# [3, 5, 6]
# John possui 3 maçãs
# Mary possui 5 maçãs
# Adam possui 6 maçãs

# %%
i = 5
j = 2

i += 2 * j

print(i)
# Out:
# 9

# %%
kilometers = 1
miles = 7.38

miles_to_kilometers = miles * 1.61
kilometers_to_miles = kilometers * 0.62

print(miles, "milhas é", round(miles_to_kilometers, 2), "quilômetros")
print(kilometers, "quilômetros é", round(kilometers_to_miles, 2), "milhas")
# Out:
# 7.38 milhas é 11.88 quilômetros
# 1 quilômetros é 0.62 milhas

# %%
def km_to_miles(x):
  x *= 0.62
  return x

def miles_to_km(x):
  x *= 1.6
  return x

km_to_miles(2)
# Out:
# 1.24

# %% [markdown]
# <h1>Input</h1>

# %%
print("Conta-me qualquer coisa...")
anything = input()
print("Hum...", anything, "... Realmente?")
# Out:
# Conta-me qualquer coisa...
# qualqqqqq
# Hum... qualqqqqq ... Realmente?

# %%
valor1 = int(input("digite o primeiro valor: "))
valor2 = int(input("digite o segundo valor: "))
print('a soma dos valores é:', valor1 + valor2)
# Out:
# digite o primeiro valor: 10
# digite o segundo valor: 5
# a soma dos valores é: 15

# %%
anything = float(input("Digite um número: "))
something = anything ** 2.0
print(anything, "elevado a 2 é", something)
# Out:
# Digite um número: 20
# 20.0 elevado a 2 é 400.0

# %%
fnam = input("Posso ter seu primeiro nome, por favor? ")
lnam = input("Posso ter seu sobrenome, por favor? ")
print("Obrigado!.")
print("\nSeu nome é " + fnam + " " + lnam + ".")
# Out:
# Posso ter seu primeiro nome, por favor? Murilo
# Posso ter seu sobrenome, por favor? Neto
# Obrigado!.
#
# Seu nome é Murilo Neto.

# %%
a = float(input('defina o valor a: '))
b = float(input('defina o valor b: '))

print('a + b é: ', a + b)
print('a - b é: ', a - b)
print('a * b é: ', a * b)
print('a / b é: ', a / b)
# Out:
# defina o valor a: 5
# defina o valor b: 5
# a + b é:  10.0
# a - b é:  0.0
# a * b é:  25.0
# a / b é:  1.0

# %% [markdown]
# <h1>Tomada de decisão</h1>

# %%
var = 0 # Atribuindo 0 a var
print(var == 0)

var = 1 # Atribuindo 1 a var
print(var == 0)
# Out:
# True
# False

# %%
var = 0  # Atribuindo 0 a var
print(var != 0)

var = 1  # Atribuindo 1 a var
print(var != 0)
# Out:
# False
# True

# %%
num = int(input("Insira um numero inteiro: "))
print(num >= 100)
# Out:
# Insira um numero inteiro: 10
# False

# %%
while True:
  num = input("Insira um numero inteiro (caso queira sair digite \"sair\"): ")
  if num == "sair":
    print('você saiu do sistema')
    break
  print(int(num) >= 100)
# Out:
# Insira um numero inteiro (caso queira sair digite "sair"): 1
# False
# Insira um numero inteiro (caso queira sair digite "sair"): 99
# False
# Insira um numero inteiro (caso queira sair digite "sair"): 10
# False
# Insira um numero inteiro (caso queira sair digite "sair"): sair
# você saiu do sistema

# %%
number1 = int(input("Digite o primeiro número: "))
number2 = int(input("Digite o segundo número: "))

if number1 > number2:
    larger_number = number1
else:
    larger_number = number2

print("O maior número é:", larger_number)
# Out:
# Digite o primeiro número: 50
# Digite o segundo número: 388
# O maior número é: 388

# %%
number1 = int(input("Digite o primeiro número: "))
number2 = int(input("Digite o segundo número: "))

if number1 > number2: larger_number = number1
else: larger_number = number2

print("O maior número é:", larger_number)
# Out:
# Digite o primeiro número: 20
# Digite o segundo número: 1
# O maior número é: 20

# %%
number1 = int(input("Digite o primeiro número: "))
number2 = int(input("Digite o segundo número: "))
number3 = int(input("Digite o terceiro número: "))

largest_number = max(number1, number2, number3)

print("O maior número é:", largest_number)
# Out:
# Digite o primeiro número: 50
# Digite o segundo número: 2
# Digite o terceiro número: 1
# O maior número é: 50

# %%
while True:
  resposta = input("Me dê um GRANDE Lirio: ")
  if resposta == "LIRIO":
    print("Lirio é a melhor planta de todos os tempos")
    break
  elif resposta == "lirio":
    print("não, eu quero um lirio MAIOR")
  elif resposta == "Lirio":
    print("não, eu quero um Lirio MAIOR")
  else:
    print("isso é uma", resposta, "eu quero um GRANDE Lirio!!!")
# Out:
# Me dê um GRANDE Lirio: Lirio
# não, eu quero um Lirio MAIOR
# Me dê um GRANDE Lirio: lirio
# não, eu quero um lirio MAIOR
# Me dê um GRANDE Lirio: rosa
# isso é uma rosa eu quero um GRANDE Lirio!!!
# Me dê um GRANDE Lirio: LIRIO
# Lirio é a melhor planta de todos os tempos

# %%
# Armazene o maior número atual aqui.
largest_number = -999999999

# Insira o primeiro valor.
number = int(input("Digite um número ou digite -1 para parar: "))

# Se o número não for igual a -1, continue.
while number != -1:
    # O número é maior que o maior_número?
    if number > largest_number:
        # Sim, atualize o maior_número.
        largest_number = number
    # Insira o próximo número.
    number = int(input("Digite um número ou digite -1 para parar: "))

# Imprima o maior número.
print("O maior número é:", largest_number)
# Out:
# Digite um número ou digite -1 para parar: 1
# Digite um número ou digite -1 para parar: -1
# O maior número é: 1

# %%
# Um programa que lê uma sequência de números
# e conta quantos números são pares e quantos são ímpares.
# O programa termina quando zero é digitado.

odd_numbers = 0
even_numbers = 0

# Leia o primeiro número.
number = int(input("Digite um número ou digite 0 para parar: "))

# 0 termina a execução.
while number != 0:
    # Verifique se o número é ímpar.
    if number % 2 == 1:
        # Aumente o contador odd_numbers.
        odd_numbers += 1
    else:
        # Aumente o contador even_numbers.
        even_numbers += 1
    # Leia o número seguinte.
    number = int(input("Digite um número ou digite 0 para parar: "))

# Imprimir resultados.
print("Números ímpares contam:", odd_numbers)
print("Números pares contam:", even_numbers)
# Out:
# Digite um número ou digite 0 para parar: 10
# Digite um número ou digite 0 para parar: 2
# Digite um número ou digite 0 para parar: 3
# Digite um número ou digite 0 para parar: 5
# Digite um número ou digite 0 para parar: 0
# Números ímpares contam: 2
# Números pares contam: 2

# %%
counter = 5
while counter != 0:
    print("Dentro do laço.", counter)
    counter -= 1
print("Fora do circuito.", counter)
# Out:
# Dentro do laço. 5
# Dentro do laço. 4
# Dentro do laço. 3
# Dentro do laço. 2
# Dentro do laço. 1
# Fora do circuito. 0

# %% [markdown]
# Cenário
# Um jovem mágico escolheu um número secreto. Ele o ocultou em uma variável chamada secret_number. Ele quer que todos que executam seu programa joguem o jogo Adivinhe o número secreto e adivinhem qual número ele escolheu para eles. Quem não adivinhar o número ficará para sempre em um loop infinito! Infelizmente, ele não sabe como completar o código.
#
# Sua tarefa é ajudar o mágico a preencher o código no editor de forma que o código:
#
# solicitará que o usuário insira um número inteiro;
# vai usar um while loop;
# verificará se o número inserido pelo usuário é igual ao número escolhido pelo mágico. Se o número escolhido pelo usuário for diferente do número secreto do mago, o usuário deverá ver a mensagem "Ha ha! Você está preso no meu loop!" E será solicitado a inserir um número novamente. Se o número inserido pelo usuário corresponder ao número escolhido pelo mago, ele deverá ser impresso na tela, e o mago deve dizer as seguintes palavras: "Muito bem, trouxa! Você está livre agora."
# O mágico está contando com você! Não o desaponte.
#
# INFORMAÇÕES EXTRA
# A propósito, observe a função print(). A maneira como usamos aqui é chamada de impressão de várias linhas. Você pode usar aspas triplas para imprimir sequências de caracteres em várias linhas para facilitar a leitura ou criar um design especial baseado em texto. Experimente.

# %%
secret_number = 777

print(
"""
+===================================+
| Bem vindo ao meu jogo, trouxa!    |
| Insira um número inteiro          |
| e adivinhar o número que tenho    |
| escolhidos para você.             |
| Então, qual é o número secreto?   |
+===================================+
""")

#loop para verificar a resposta do usuario, enquanto for vdd faça:
while True:
  #recebe a resposta formata pra int e atribui a variavel 'resposta'
  print("Ha ha! Você está preso no meu loop!")
  resposta = int(input("Digite o numero secreto:"))
  #se a resposta for igual ao numero secreto, envia mensagem e para o loop
  if resposta == secret_number:
    print('Muito bem, trouxa! Você está livre agora.')
    break
# Out:
# +===================================+
# | Bem vindo ao meu jogo, trouxa!    |
# | Insira um número inteiro          |
# | e adivinhar o número que tenho    |
# | escolhidos para você.             |
# | Então, qual é o número secreto?   |
# +===================================+
#
# Ha ha! Você está preso no meu loop!
# Digite o numero secreto:123
# Ha ha! Você está preso no meu loop!
# Digite o numero secreto:456
# Ha ha! Você está preso no meu loop!
# Digite o numero secreto:777
# Muito bem, trouxa! Você está livre agora.

# %%
secret_number = 777

print(
"""
+===================================+
| Bem vindo ao meu jogo, trouxa!    |
| Insira um número inteiro          |
| e adivinhar o número que tenho    |
| escolhidos para você.             |
| Então, qual é o número secreto?   |
+===================================+
""")

resposta = int(input("Digite o numero secreto:"))

while resposta != secret_number:
  print("Ha ha! Você está preso no meu loop!")
  resposta = int(input("Digite o numero secreto:"))
print('Muito bem, trouxa! Você está livre agora.')
# Out:
# +===================================+
# | Bem vindo ao meu jogo, trouxa!    |
# | Insira um número inteiro          |
# | e adivinhar o número que tenho    |
# | escolhidos para você.             |
# | Então, qual é o número secreto?   |
# +===================================+
#
# Digite o numero secreto:123
# Ha ha! Você está preso no meu loop!
# Digite o numero secreto:123
# Ha ha! Você está preso no meu loop!
# Digite o numero secreto:11
# Ha ha! Você está preso no meu loop!
# Digite o numero secreto:777
# Muito bem, trouxa! Você está livre agora.

# %%
for i in range(2, 8):
    print("O valor de i é atualmente", i)
# Out:
# O valor de i é atualmente 2
# O valor de i é atualmente 3
# O valor de i é atualmente 4
# O valor de i é atualmente 5
# O valor de i é atualmente 6
# O valor de i é atualmente 7

# %%
for i in range(1,11):
  print(f'-----------\n\ntabuada do {i}\n')
  for j in range(1,10):
    print(i,'x',j,'=', i * j)
# Out:
# -----------
#
# tabuada do 1
#
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# -----------
#
# tabuada do 2
#
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# -----------
#
# tabuada do 3
#
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# -----------
#
# tabuada do 4
#
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# -----------
#
# tabuada do 5
#
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# -----------
#
# tabuada do 6
#
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# -----------
#
# tabuada do 7
#
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# ...

# %%
for i in range(51):
  if i != 0 and i % 2 == 0:
    print('o numero', i, 'é par')
  elif i != 0 and i % 2 != 0:
    print('o numero', i, 'é impar')
# Out:
# o numero 1 é impar
# o numero 2 é par
# o numero 3 é impar
# o numero 4 é par
# o numero 5 é impar
# o numero 6 é par
# o numero 7 é impar
# o numero 8 é par
# o numero 9 é impar
# o numero 10 é par
# o numero 11 é impar
# o numero 12 é par
# o numero 13 é impar
# o numero 14 é par
# o numero 15 é impar
# o numero 16 é par
# o numero 17 é impar
# o numero 18 é par
# o numero 19 é impar
# o numero 20 é par
# o numero 21 é impar
# o numero 22 é par
# o numero 23 é impar
# o numero 24 é par
# o numero 25 é impar
# o numero 26 é par
# o numero 27 é impar
# o numero 28 é par
# o numero 29 é impar
# o numero 30 é par
# o numero 31 é impar
# o numero 32 é par
# o numero 33 é impar
# o numero 34 é par
# o numero 35 é impar
# o numero 36 é par
# o numero 37 é impar
# o numero 38 é par
# o numero 39 é impar
# o numero 40 é par
# o numero 41 é impar
# o numero 42 é par
# o numero 43 é impar
# o numero 44 é par
# o numero 45 é impar
# o numero 46 é par
# o numero 47 é impar
# o numero 48 é par
# ...

# %%
for i in range(0,51,2):
  print(i, 'é par')
# Out:
# 0 é par
# 2 é par
# 4 é par
# 6 é par
# 8 é par
# 10 é par
# 12 é par
# 14 é par
# 16 é par
# 18 é par
# 20 é par
# 22 é par
# 24 é par
# 26 é par
# 28 é par
# 30 é par
# 32 é par
# 34 é par
# 36 é par
# 38 é par
# 40 é par
# 42 é par
# 44 é par
# 46 é par
# 48 é par
# 50 é par

# %%
import time

# Escreva um loop for que conte até cinco
for i in range(1,6):
   # Corpo do loop - exiba o número de iteração do loop e a palavra "Mississippi".
   print(i, "Mississippi")
   # Corpo do loop - use: time.sleep(1)
   time.sleep(1)
# Escreva uma função print com a mensagem final.
print('Pronto ou não, aqui vou eu!')
# Out:
# 1 Mississippi
# 2 Mississippi
# 3 Mississippi
# 4 Mississippi
# 5 Mississippi
# Pronto ou não, aqui vou eu!

# %%
# break - exemplo

print("The break instrução:")
for i in range(1, 6):
    if i == 3:
        break
    print("Dentro do laço.", i)
print("Fora do loop.")
# Out:
# The break instrução:
# Dentro do laço. 1
# Dentro do laço. 2
# Fora do loop.

# %%
# continue - exemplo

print("The continue instrução:")
for i in range(1, 6):
    if i == 3:
        continue
    print("Dentro do laço.", i)
print("Fora do loop.")
# Out:
# The continue instrução:
# Dentro do laço. 1
# Dentro do laço. 2
# Dentro do laço. 4
# Dentro do laço. 5
# Fora do loop.

# %%
while True:
    palavra = input("escreva a palavra chupacabra: ")
    if palavra == "chupacabra":
        break
print("Você saiu do loop com sucesso")
# Out:
# escreva a palavra chupacabra: chupacabra
# Você saiu do loop com sucesso

# %%
nome = input("informe seu nome: ").upper()
print(nome)
# Out:
# informe seu nome: olaaa
# OLAAA

# %%
nome = input("informe seu nome: ").upper()

for letra in nome:
  if letra in 'AEIOU':
    continue
  print(letra)
# Out:
# informe seu nome: murilo
# M
# U
# R
# I
# L
# O

# %%
nome = input("informe seu nome: ").upper()

for letra in nome:
  if letra in 'AEIOU':
    continue
  print(letra, end='')
# Out:
# informe seu nome: murilo
# MRL

# %%
for i in range(1,11):
  if i % 2 != 0:
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(1,11,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for email in "john.smith@pythoninstitute.org":
    if email == "@":
        break
    print(email, end='')
# Out:
# john.smith

# %%
var = 1

# Exemplo 1:
print(var > 0)
print(not (var <= 0))


# Exemplo 2:
print(var != 0)
print(not (var == 0))
# Out:
# True
# True
# True
# True

# %%
var1 = int(input())
var2 = int(input())
var3 = int(input())
var4 = int(input())
var5 = int(input())
var6 = int(input())
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
numbers = [10, 5, 7, 2, 1]
print(numbers)
# Out:
# [10, 5, 7, 2, 1]

# %%
numbers = [10, 5, 7, 2, 1]
print("Conteúdos originais da lista:", numbers)  # Imprimindo o conteúdo original da lista.

numbers[1] = numbers[4]
print("lista:", numbers)
# Out:
# Conteúdos originais da lista: [10, 5, 7, 2, 1]
# lista: [10, 1, 7, 2, 1]

# %%
print(len(numbers))
# Out:
# 5

# %%
del numbers[1]

print(len(numbers))

print(numbers)
# Out:
# 4
# [10, 7, 2, 1]

# %%
# Esta é uma lista atual de números ocultos no hat.
hat_list = [1, 2, 3, 4, 5]

# Etapa 1: escreva uma linha de código que solicita ao usuário
num_user = int(input('digite um numero: '))

# que substitua o número do meio por um número inteiro inserido pelo usuário.
indice_meio = len(hat_list) // 2
hat_list[indice_meio] = num_user
print(hat_list)

# Etapa 2: escreva uma linha de código que remova o último elemento da lista.
del hat_list[-1]

# Etapa 3: escreva uma linha de código que imprima o comprimento da lista atual
print(hat_list)
print(len(hat_list))
# Out:
# digite um numero: 165
# [1, 2, 165, 4, 5]
# [1, 2, 165, 4]
# 4

# %%
hat_list.append(52)
print(hat_list)
# Out:
# [1, 2, 165, 4, 52]

# %%
hat_list.insert(0, 33)
print(hat_list)
# Out:
# [33, 1, 2, 165, 4, 52]

# %%
my_list = [] # Criando uma lista vazia.

for i in range(5):
   my_list.append (i + 1)

print (my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
my_list = []  # Criando uma lista vazia.

for i in range(5):
    my_list.insert(0, i + 1)

print(my_list)
# Out:
# [5, 4, 3, 2, 1]

# %%
my_list = [10, 1, 8, 3, 5]

total = 0

for i in range(len(my_list)):

  total += my_list[i]

print(total)
# Out:
# 27

# %%
my_list = [10, 1, 8, 3, 5]
total = 0

for i in my_list:
    total += i

print(total)
# Out:
# 27

# %%
my_list = ["branco", "roxo", "azul", "amarelo", "verde"]

for color in my_list:
    print(color)
# Out:
# branco
# roxo
# azul
# amarelo
# verde

# %%
lst = [1, 2, 3, 4, 5]
lst.insert(1, 6)
del lst[0]
lst.append(1)

print(lst)
# Out:
# [6, 2, 3, 4, 5, 1]

# %%
my_list = [8,10,6,2,4]
my_list.sort()
print(my_list)
# Out:
# [2, 4, 6, 8, 10]

# %%
lst = ["D", "F", "A", "Z"]
lst.sort()

print(lst)
# Out:
# ['A', 'D', 'F', 'Z']

# %%
a = 3
b = 1
c = 2

lst = [a, c, b]
lst.sort()

print(lst)
# Out:
# [1, 2, 3]

# %%
a = "A"
b = "B"
c = "C"
d = " "

lst = [a, b, c, d]
lst.reverse()

print(lst)
# Out:
# [' ', 'C', 'B', 'A']

# %%
my_list = [10, 8, 6, 4, 2]
new_list = my_list[:3]
print(new_list)
# Out:
# [10, 8, 6]

# %%
my_list = [10, 8, 6, 4, 2]
new_list = my_list[1:3]
print(new_list)
# Out:
# [8, 6]

# %%
# Copiar a lista inteira.
list_1 = [1]
list_2 = list_1 [:]
list_1 [0] = 2
print (list_2)

# Copiando parte da lista.
my_list = [10, 8, 6, 4, 2]
new_list = my_list [1: 3]
print(new_list)
# Out:
# [1]
# [8, 6]

# %%
my_list = [10, 8, 6, 4, 2]
new_list = my_list[1:-1]
print(new_list)
# Out:
# [8, 6, 4]

# %%
# deletando valores da lista
my_list = [10, 8, 6, 4, 2]
del my_list[:]
print(my_list)
# Out:
# []

# %%
# deletando a lista
my_list = [10, 8, 6, 4, 2]
del my_list
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1924733505.py in <cell line: 0>()
#       2 my_list = [10, 8, 6, 4, 2]
#       3 del my_list
# ----> 4 print(my_list)
#
# NameError: name 'my_list' is not defined

# %%
list_1 = ["A", "B", "C"]
list_2 = list_1[:]
list_3 = list_2[:]

del list_1[0]
del list_2[0]

print(list_3)
# Out:
# ['A', 'B', 'C']

# %%
my_list = [1, 2, "in", True, "ABC"]

print(1 in my_list)  # outputs True
print("A" not in my_list)  # outputs True
print(3 not in my_list)  # outputs True
print(False in my_list)  # outputs False
# Out:
# True
# True
# True
# False

# %%
alimentos = [['feijão','arroz'],['frango','carne']]

print(f"eu prefiro {alimentos[0][0]} e {alimentos[0][1]} com {alimentos[1][0]}.")
# Out:
# eu prefiro feijão e arroz com frango.

# %%
alimentos = [['feijão','arroz'],['frango','carne']]

for comida in alimentos:
  for item in comida:
    print(item)
# Out:
# feijão
# arroz
# frango
# carne

# %%
mapa_assentos = [
    ['O', 'O', 'L', 'L', 'L'],
    ['L', 'L', 'L', 'L', 'L'],
    ['L', 'L', 'L', 'O', 'L'],
    ['L', 'L', 'L', 'L', 'L'],
    ['L', 'L', 'L', 'L', 'L']
]


total = len(mapa_assentos) * len(mapa_assentos[0])
livres = 0
for fileira in mapa_assentos:
  for assento in fileira:
    if assento == 'L':
      livres += 1

for map_a in mapa_assentos:
  print(map_a)

print(f'\nTotal de assentos: {total}')
print(f'Livres: {livres}')
print(f'Ocupados: {total - livres}')
# Out:
# ['O', 'O', 'L', 'L', 'L']
# ['L', 'L', 'L', 'L', 'L']
# ['L', 'L', 'L', 'O', 'L']
# ['L', 'L', 'L', 'L', 'L']
# ['L', 'L', 'L', 'L', 'L']
#
# Total de assentos: 25
# Livres: 22
# Ocupados: 3

# %%
def message():
  print("entre um valor: ")

print('começamos aqui')
message()
print('terminamos aqui')
# Out:
# começamos aqui
# entre um valor:
# terminamos aqui

# %%
def hello(name): # definindo uma função
    print("Olá,", name) # o corpo da função


name = input("Entre um valor: ")

hello(name) # chamando a função
# Out:
# Entre um valor: murilo
# Olá, murilo

# %%
def message(number):
    print("Digite um número:", number)

number = 1234
message(1)
print(number)
# Out:
# Digite um número: 1
# 1234

# %%
def introduction(first_name, last_name):
    print("Olá meu nome é", first_name, last_name)

introduction("Luke", "Skywalker")
introduction("Jesse", "Quick")
introduction("Clark", "Kent")
# Out:
# Olá meu nome é Luke Skywalker
# Olá meu nome é Jesse Quick
# Olá meu nome é Clark Kent

# %%
def introduction(first_name, last_name):
    print("Olá meu nome é", first_name, last_name)

introduction(first_name = "James", last_name = "Bond")
introduction(last_name = "Skywalker", first_name = "Luke")
# Out:
# Olá meu nome é James Bond
# Olá meu nome é Luke Skywalker

# %%
def introduction(first_name, last_name="Smith"):
     print("Olá meu nome é", first_name, last_name)

introduction("James", "Doe")
# Out:
# Olá meu nome é James Doe

# %%
def happy_new_year(wishes = True):
  for i in range(1,4):
    print(i,'...')
  if not wishes:
    return

  print("Feliz novo ano!")

happy_new_year()
# Out:
# 1 ...
# 2 ...
# 3 ...
# Feliz novo ano!

# %%
def boring_function():
  return 123

x = boring_function()

print('A aborrecimento é', x)
# Out:
# A aborrecimento é 123

# %%
def boring_function():
    print("'Modo de tédio' ON.")
    return 123

print("Esta lição é interessante!")
boring_function()
print("Essa aula é chata...")
# Out:
# Esta lição é interessante!
# 'Modo de tédio' ON.
# Essa aula é chata...

# %%
def strange_function(n):
  if(n % 2 == 0):
    return True

strange_function(4)
# Out:
# True

# %%
def forca():
  palavra = input('digita a palavra da forca: ')

  global palavra_secreta
  palavra_secreta = palavra.upper()

  for letras in palavra:
    print('_', end=' ')

  print('\n')

  tentativa = input('digite uma letra: ').upper()

  if tentativa in palavra_secreta:
    print('')
  else:
    print('errou')

forca()
# Out:
# digita a palavra da forca: teste
# _ _ _ _ _
#
# digite uma letra: pa
# errou

# %%
def my_function():
 global var
 var = 2
 print("Eu conheço aquela variável?", var)


var = 1
my_function()
print(var)
# Out:
# Eu conheço aquela variável? 2
# 2

# %%
tuple_1 = (1, 2, 4, 8)
tuple_2 = 1., .5, .25, .125

print(tuple_1)
print(tuple_2)
# Out:
# (1, 2, 4, 8)
# (1.0, 0.5, 0.25, 0.125)

# %%
my_tuple = (1, 10, 100)

t1 = my_tuple + (1000, 10000)
t2 = my_tuple * 3

print(len(t2))
print(t1)
print(t2)
print(10 in my_tuple)
print(-10 not in my_tuple)
# Out:
# 9
# (1, 10, 100, 1000, 10000)
# (1, 10, 100, 1, 10, 100, 1, 10, 100)
# True
# True

# %%
dictionary = {"gato": "chat", "cachorro": "chien", "cavalo": "cheval"}
phone_numbers = {'chefe' : 5551234567, 'Suzy' : 22657854310}
empty_dictionary = {}

# %%
print(dictionary['gato'])
print(phone_numbers['Suzy'])
# Out:
# chat
# 22657854310

# %%
dictionary = {"gato": "chat", "cachorro": "chien", "cavalo": "cheval"}
words = ['gato', 'lion', 'cavalo']

for word in words:
    if word in dictionary:
        print(word, "->", dictionary[word])
    else:
        print(word, "não está no dicionário")
# Out:
# gato -> chat
# lion não está no dicionário
# cavalo -> cheval

# %%
dictionary = {"gato": "chat", "cachorro": "chien", "cavalo": "cheval"}

for english, french in dictionary.items():
    print(english, "->", french)
# Out:
# gato -> chat
# cachorro -> chien
# cavalo -> cheval

# %%
dictionary = {"gato": "chat", "cachorro": "chien", "cavalo": "cheval"}

dictionary['gato'] = 'minou'
print(dictionary)
# Out:
# {'gato': 'minou', 'cachorro': 'chien', 'cavalo': 'cheval'}

# %%
print(sorted(dictionary.items()))

print(sorted(dictionary.keys()))

print(sorted(dictionary.values()))
# Out:
# [('cachorro', 'chien'), ('cavalo', 'cheval'), ('gato', 'minou')]
# ['cachorro', 'cavalo', 'gato']
# ['cheval', 'chien', 'minou']

# %%
try:
 value = int(input('Digite um número natural: '))
 print('O recíproco de', value, 'é', 1/value)
except ValueError:
 print('Eu não sei o que fazer.')
except ZeroDivisionError:
 print('A divisão por zero não é permitida em nosso Universo.')
# Out:
# Digite um número natural: 00
# A divisão por zero não é permitida em nosso Universo.

# %%
try:
  value = int (input('Insira um número natural:'))
  print('O recíproco de', value, 'é', 1 / value)
except ValueError:
  print('Não sei o que fazer.' )
except ZeroDivisionError:
  print('Divisão por zero não é permitida em nosso universo.')
except:
  print('algo de estranho aconteceu aqui ... Desculpe! ')
# Out:
# Insira um número natural:15
# O recíproco de 15 é 0.06666666666666667
